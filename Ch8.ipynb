# %%
import numpy as np
import sys
from keras.datasets import mnist
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 3s 0us/step

# %%
images, labels = (x_train[0:1000].reshape(1000, 28*28) \
                                     /255, y_train[0:1000])

# %%
one_hot_labels = np.zeros((len(labels),10))

# %%
for i,l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

# %%
test_images = x_test.reshape(len(x_test),28*28) / 255
test_labels = np.zeros((len(y_test),10))
for i,l in enumerate(y_test):
    test_labels[i][l] = 1

# %%
np.random.seed(1)

# %%
relu = lambda x: (x>=0) * x
relu2deriv = lambda x: x>=0

# %%
alpha = 0.005
iterations = 350
hidden_size = 40
pixels_per_image = 784
num_labels = 10

# %%
weights_0_1 = 0.2*np.random.random((pixels_per_image, hidden_size)) - 0.1
weights_1_2 = 0.2*np.random.random((hidden_size, num_labels)) - 0.1

# %%
for j in range(iterations):
    error, correct_count = (0.0, 0)
    
    for i in range(len(images)):
        layer_0 = images[i:i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)
        
        error += np.sum((labels[i:i+1] - layer_2) ** 2)
        correct_count += int(np.argmax(layer_2) == \
                                        np.argmax(labels[i:i+1]))
        
        layer_2_delta = (labels[i:i+1] - layer_2)
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * relu2deriv(layer_1)
        
        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 += alpha * layer_0.T.dot(layer_1_delta)
        
        sys.stdout.write("\r"+ \
                         " I:"+str(j)+ \
                         " Error:" + str(error/float(len(images)))[0:5] +\
                         " Correct:" + str(correct_count/float(len(images))))
# Out:
#  I:0 Error:0.413 Correct:0.218
#  I:0 Error:0.711 Correct:0.521
#  I:1 Error:0.206 Correct:0.295
#  I:1 Error:0.434 Correct:0.63
#  I:2 Error:0.098 Correct:0.161
#  I:2 Error:0.297 Correct:0.522
#  I:3 Error:0.061 Correct:0.119
#  I:3 Error:0.241 Correct:0.498
#  I:3 Error:0.378 Correct:0.765
#  I:4 Error:0.154 Correct:0.358
#  I:4 Error:0.354 Correct:0.773
#  I:5 Error:0.094 Correct:0.219
#  I:5 Error:0.269 Correct:0.635
#  I:6 Error:0.087 Correct:0.219
#  I:6 Error:0.243 Correct:0.605
#  I:7 Error:0.031 Correct:0.076
#  I:7 Error:0.139 Correct:0.39
#  I:7 Error:0.294 Correct:0.765
#  I:8 Error:0.115 Correct:0.335
#  I:8 Error:0.305 Correct:0.829
#  I:9 Error:0.107 Correct:0.315
#  I:9 Error:0.243 Correct:0.69
#  I:10 Error:0.088 Correct:0.254
#  I:10 Error:0.199 Correct:0.576
#  I:11 Error:0.024 Correct:0.073
#  I:11 Error:0.191 Correct:0.571
#  I:12 Error:0.029 Correct:0.093
#  I:349 Error:0.108 Correct:1.099

# %%
# NOW TO TEST IT (AND WATCH IT FAIL)

# %%
for j in range(1):
    error, correct_count = (0.0, 0)
    
    for i in range(len(test_images)):
        layer_0 = test_images[i:i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)
        
        error += np.sum((test_labels[i:i+1] - layer_2) ** 2)
        correct_count += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
        
    sys.stdout.write(" Test-Err:" + str(error/float(len(test_images)))[0:5] +\
                         " Test-Acc:" + str(correct_count/float(len(test_images))))
    print()
# Out:
#  Test-Err:0.653 Test-Acc:0.7073
